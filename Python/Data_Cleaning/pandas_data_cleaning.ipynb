# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Data Cleaning in Pandas (SQL to Advanced)\n",
    "**For SQL Experts Transitioning to Pandas**"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Basic Operations (SQL → Pandas)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "\n",
    "# Create a sample DataFrame\n",
    "data = {\n",
    "    'id': [1, 2, 3, 4],\n",
    "    'name': ['Alice', 'Bob', None, 'David'],\n",
    "    'value': [100, None, 150, 200],\n",
    "    'category': ['A', 'B', 'A', 'B']\n",
    "}\n",
    "df = pd.DataFrame(data)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 1. Filtering Rows (SQL WHERE)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# SQL: SELECT * FROM table WHERE value > 100 AND category = 'A'\n",
    "filtered_df = df[(df['value'] > 100) & (df['category'] == 'A')]"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 2. Handling NULLs (SQL COALESCE)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# SQL: SELECT COALESCE(value, 0) FROM table\n",
    "df['value'] = df['value'].fillna(0)\n",
    "df['name'] = df['name'].fillna('Unknown')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Advanced Operations"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 3. Group Imputation (SQL Window Functions)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Replace NULLs with group mean\n",
    "df['value'] = df.groupby('category')['value'].transform(lambda x: x.fillna(x.mean()))"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 4. Advanced String Manipulation"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Extract numbers from strings\n",
    "df['id'] = df['name'].str.extract(r'(\\d+)').astype(float)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 5. Optimized Memory Usage"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Reduce memory usage\n",
    "df['category'] = df['category'].astype('category')\n",
    "df['id'] = pd.to_numeric(df['id'], downcast='integer')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Case Study: Full Pipeline"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Clean a messy dataset\n",
    "clean_df = (\n",
    "    df\n",
    "    .dropna(subset=['name'])\n",
    "    .assign(value=lambda x: x['value'] * 2)\n",
    "    .query(\"category == 'A'\")\n",
    ")\n",
    "clean_df"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.9.6"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 20
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Data Cleaning in Pandas (SQL to Advanced)\n",
#       8     "**For SQL Experts Transitioning to Pandas**"
#       9    ]
#      10   },
#      11   {
#      12    "cell_type": "markdown",
#      13    "metadata": {},
#      14    "source": [
#      15     "## Basic Operations (SQL → Pandas)"
#      16    ]
#      17   },
#      18   {
#      19    "cell_type": "code",
# ---> 20    "execution_count": null,
#      21    "metadata": {},
#      22    "outputs": [],
#      23    "source": [
#      24     "import pandas as pd\n",
#      25     "import numpy as np\n",
#      26     "\n",
#      27     "# Create a sample DataFrame\n",
#      28     "data = {\n",
#      29     "    'id': [1, 2, 3, 4],\n",
#      30     "    'name': ['Alice', 'Bob', None, 'David'],\n",
#      31     "    'value': [100, None, 150, 200],\n",
#      32     "    'category': ['A', 'B', 'A', 'B']\n",
#      33     "}\n",
#      34     "df = pd.DataFrame(data)"
#      35    ]
#      36   },
#      37   {
#      38    "cell_type": "markdown",
#      39    "metadata": {},
#      40    "source": [
#      41     "### 1. Filtering Rows (SQL WHERE)"
#      42    ]
#      43   },
#      44   {
#      45    "cell_type": "code",
#      46    "execution_count": null,
#      47    "metadata": {},
#      48    "outputs": [],
#      49    "source": [
#      50     "# SQL: SELECT * FROM table WHERE value > 100 AND category = 'A'\n",
#      51     "filtered_df = df[(df['value'] > 100) & (df['category'] == 'A')]"
#      52    ]
#      53   },
#      54   {
#      55    "cell_type": "markdown",
#      56    "metadata": {},
#      57    "source": [
#      58     "### 2. Handling NULLs (SQL COALESCE)"
#      59    ]
#      60   },
#      61   {
#      62    "cell_type": "code",
#      63    "execution_count": null,
#      64    "metadata": {},
#      65    "outputs": [],
#      66    "source": [
#      67     "# SQL: SELECT COALESCE(value, 0) FROM table\n",
#      68     "df['value'] = df['value'].fillna(0)\n",
#      69     "df['name'] = df['name'].fillna('Unknown')"
#      70    ]
#      71   },
#      72   {
#      73    "cell_type": "markdown",
#      74    "metadata": {},
#      75    "source": [
#      76     "## Advanced Operations"
#      77    ]
#      78   },
#      79   {
#      80    "cell_type": "markdown",
#      81    "metadata": {},
#      82    "source": [
#      83     "### 3. Group Imputation (SQL Window Functions)"
#      84    ]
#      85   },
#      86   {
#      87    "cell_type": "code",
#      88    "execution_count": null,
#      89    "metadata": {},
#      90    "outputs": [],
#      91    "source": [
#      92     "# Replace NULLs with group mean\n",
#      93     "df['value'] = df.groupby('category')['value'].transform(lambda x: x.fillna(x.mean()))"
#      94    ]
#      95   },
#      96   {
#      97    "cell_type": "markdown",
#      98    "metadata": {},
#      99    "source": [
#     100     "### 4. Advanced String Manipulation"
#     101    ]
#     102   },
#     103   {
#     104    "cell_type": "code",
#     105    "execution_count": null,
#     106    "metadata": {},
#     107    "outputs": [],
#     108    "source": [
#     109     "# Extract numbers from strings\n",
#     110     "df['id'] = df['name'].str.extract(r'(\\d+)').astype(float)"
#     111    ]
#     112   },
#     113   {
#     114    "cell_type": "markdown",
#     115    "metadata": {},
#     116    "source": [
#     117     "### 5. Optimized Memory Usage"
#     118    ]
#     119   },
#     120   {
#     121    "cell_type": "code",
#     122    "execution_count": null,
#     123    "metadata": {},
#     124    "outputs": [],
#     125    "source": [
#     126     "# Reduce memory usage\n",
#     127     "df['category'] = df['category'].astype('category')\n",
#     128     "df['id'] = pd.to_numeric(df['id'], downcast='integer')"
#     129    ]
#     130   },
#     131   {
#     132    "cell_type": "markdown",
#     133    "metadata": {},
#     134    "source": [
#     135     "## Case Study: Full Pipeline"
#     136    ]
#     137   },
#     138   {
#     139    "cell_type": "code",
#     140    "execution_count": null,
#     141    "metadata": {},
#     142    "outputs": [],
#     143    "source": [
#     144     "# Clean a messy dataset\n",
#     145     "clean_df = (\n",
#     146     "    df\n",
#     147     "    .dropna(subset=['name'])\n",
#     148     "    .assign(value=lambda x: x['value'] * 2)\n",
#     149     "    .query(\"category == 'A'\")\n",
#     150     ")\n",
#     151     "clean_df"
#     152    ]
#     153   }
#     154  ],
#     155  "metadata": {
#     156   "kernelspec": {
#     157    "display_name": "Python 3",
#     158    "language": "python",
#     159    "name": "python3"
#     160   },
#     161   "language_info": {
#     162    "name": "python",
#     163    "version": "3.9.6"
#     164   }
#     165  },
#     166  "nbformat": 4,
#     167  "nbformat_minor": 2
#     168 }
#
# NameError: name 'null' is not defined
